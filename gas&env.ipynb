# %% [markdown]
# # Multi-Model Training & Evaluation Pipeline
#
# This notebook trains and evaluates multiple models on a tabular dataset. Models included:
#
# - SVM (RBF)
# - Random Forest
# - ANN (2-layer)
# - ANN (3-layer)
# - K-Nearest Neighbors (KNN)
# - Gradient Boosting
# - XGBoost
# - CNN (1D for tabular data)
#
# **Dataset files (expected):** `ds_34_x_train.csv`, `ds_34_y_train.csv`, `ds_34_x_test.csv`, `ds_34_y_test.csv`.
#
# Run the cells in order. Save the notebook after running to keep the trained models saved to disk.
#
# ---

# %% [markdown]
# ## 1) Setup and Imports
# Install any missing packages (e.g., xgboost, tensorflow) in your environment before running. The cell below imports all required libraries.

# %%
# Imports
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import os
print("imports done")
# Out:
# WARNING:tensorflow:From D:\food spoilage\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# imports done

# %% [markdown]
# ## 2) Load Dataset
# Make sure the four CSV files are in the same folder as this notebook or provide full paths. The labels should be 1D arrays (one column).

# %%
# Load dataset
x_train = pd.read_csv("ds_34_x_train.csv").iloc[:, 1:10].values
y_train = pd.read_csv("ds_34_y_train.csv").iloc[:, 1].values.ravel()
x_test = pd.read_csv("ds_34_x_test.csv").iloc[:, 1:10].values
y_test = pd.read_csv("ds_34_y_test.csv").iloc[:, 1].values.ravel()

y_train = y_train - 1
y_test = y_test - 1

n_classes = len(np.unique(y_train))
n_features = x_train.shape[1]

print("Data loaded successfully!")
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape : {x_test.shape}")
print(f"y_test shape : {y_test.shape}")
# Out:
# Data loaded successfully!
# x_train shape: (18819, 9)
# y_train shape: (18819,)
# x_test shape : (8066, 9)
# y_test shape : (8066,)

# %% [markdown]
# ## 3) Helper: evaluation function
# This function prints metrics and returns a list row for the summary dataframe.

# %%
def evaluate_model(name, y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    
    print(f"\n=== {name} Evaluation ===")
    print(f"Accuracy  : {acc:.4f}")
    print(f"Precision : {prec:.4f}")
    print(f"Recall    : {rec:.4f}")
    print(f"F1 Score  : {f1:.4f}")
    
    return [name, acc, prec, rec, f1]

results = []

# 2. ### LOAD YOUR REAL TEST DATA HERE ###
# (Replacing this placeholder data)
print("WARNING: Using placeholder test data. Replace with your actual X_test and y_test.")
X_test = np.random.rand(100, 20) 
y_true_labels = np.random.randint(0, 3, size=100) 
# ### END OF DATA SECTION ###
# Out:
# WARNING: Using placeholder test data. Replace with your actual X_test and y_test.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## 4) Model: SVM (RBF)

# %%
# Define and train the model
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm_model.fit(x_train, y_train)

# Predictions on test data
y_pred = svm_model.predict(x_test)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Save model
os.makedirs("gas&env_models", exist_ok=True)
pickle.dump(svm_model, open("gas&env_models/svm_rbf_model_s.pkl", "wb"))

# Textual Summary
print("\n=== SVM (RBF) - Test Summary ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title("Confusion Matrix - SVM (RBF)")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Append to results
results.append(["SVM (RBF)", accuracy, precision, recall, f1])
# Out:
# === SVM (RBF) - Test Summary ===
# Accuracy  : 0.8194
# Precision : 0.8245
# Recall    : 0.8194
# F1 Score  : 0.8209

# %% [markdown]
# ## 5) Model: Random Forest

# %%
# Train Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

# Predict on test data
y_pred = rf_model.predict(x_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Save model
os.makedirs("gas&env_models", exist_ok=True)
pickle.dump(rf_model, open("gas&env_models/random_forest_model_s.pkl", "wb"))

# Textual Summary
print("\n=== Random Forest - Test Summary ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', cbar=False)
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Append to results
results.append(["Random Forest", accuracy, precision, recall, f1])
# Out:
# === Random Forest - Test Summary ===
# Accuracy  : 0.9990
# Precision : 0.9990
# Recall    : 0.9990
# F1 Score  : 0.9990

# %% [markdown]
# ## 6) Model: ANN (2-layer)

# %%
# Split data
n_features = x_train.shape[1]
n_classes = len(np.unique(y_train))

# Define model
ann2 = Sequential([
    Dense(64, activation='relu', input_shape=(n_features,)),
    Dense(32, activation='relu'),
    Dense(n_classes, activation='softmax')
])

# Compile model
ann2.compile(optimizer=Adam(learning_rate=0.001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# Early stopping (monitor training loss)
early_stop = EarlyStopping(
    monitor='loss',
    patience=8,
    restore_best_weights=True,
    verbose=1
)

# Train model (no validation)
history = ann2.fit(
    x_train, y_train,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate
train_loss, train_acc = ann2.evaluate(x_train, y_train, verbose=0)
test_loss, test_acc = ann2.evaluate(x_test, y_test, verbose=0)

# Predictions
y_pred = np.argmax(ann2.predict(x_test), axis=1)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Save model
os.makedirs("gas&env_models", exist_ok=True)
ann2.save("gas&env_models/ann_2layer_model_s.keras")

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== ANN (2 Layers) - Training Summary ===")
print(f"Loss       : {train_loss:.4f}")
print(f"Accuracy   : {train_acc:.4f}")

print("\n=== ANN (2 Layers) - Test Summary ===")
print(f"Loss       : {test_loss:.4f}")
print(f"Accuracy   : {test_acc:.4f}")

print("\n=== ANN (2 Layers) Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False)
plt.title("Confusion Matrix - ANN (2 Layers)")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Accuracy & Loss Curves
epochs_ran = len(history.history['accuracy'])
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(range(1, epochs_ran+1), history.history['accuracy'], label='Train Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(range(1, epochs_ran+1), history.history['loss'], label='Train Loss')
plt.title('Training Loss (Early Stopping Monitored)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:From D:\food spoilage\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From D:\food spoilage\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\food spoilage\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 589/589 [==============================] - 6s 6ms/step - loss: 14.0883 - accuracy: 0.6419
# Epoch 2/100
# 589/589 [==============================] - 3s 6ms/step - loss: 2.3376 - accuracy: 0.7185
# Epoch 3/100
# 589/589 [==============================] - 3s 6ms/step - loss: 1.8426 - accuracy: 0.7498
# Epoch 4/100
# 589/589 [==============================] - 4s 6ms/step - loss: 1.5167 - accuracy: 0.7784
# Epoch 5/100
# 589/589 [==============================] - 3s 6ms/step - loss: 1.4590 - accuracy: 0.7984
# Epoch 6/100
# 589/589 [==============================] - 4s 6ms/step - loss: 1.0571 - accuracy: 0.8220
# Epoch 7/100
# 589/589 [==============================] - 3s 6ms/step - loss: 1.2306 - accuracy: 0.8179
# Epoch 8/100
# 589/589 [==============================] - 3s 6ms/step - loss: 1.0431 - accuracy: 0.8326
# Epoch 9/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.9952 - accuracy: 0.8392
# Epoch 10/100
# 589/589 [==============================] - 3s 5ms/step - loss: 1.0716 - accuracy: 0.8371
# Epoch 11/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.8336 - accuracy: 0.8581
# Epoch 12/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.7457 - accuracy: 0.8659
# Epoch 13/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.9212 - accuracy: 0.8556
# Epoch 14/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.8402 - accuracy: 0.8537
# Epoch 15/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.5433 - accuracy: 0.8820
# Epoch 16/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.6092 - accuracy: 0.8783
# Epoch 17/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.6506 - accuracy: 0.8763
# Epoch 18/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.5994 - accuracy: 0.8792
# Epoch 19/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.5676 - accuracy: 0.8846
# Epoch 20/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.5209 - accuracy: 0.8894
# Epoch 21/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.4224 - accuracy: 0.9000
# Epoch 22/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.3539 - accuracy: 0.9087
# Epoch 23/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.3594 - accuracy: 0.9085
# Epoch 24/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.4223 - accuracy: 0.8993
# Epoch 25/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.3095 - accuracy: 0.9163
# Epoch 26/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.3249 - accuracy: 0.9116
# Epoch 27/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2763 - accuracy: 0.9193
# Epoch 28/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2867 - accuracy: 0.9194
# Epoch 29/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2289 - accuracy: 0.9261
# Epoch 30/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.2024 - accuracy: 0.9348
# Epoch 31/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2073 - accuracy: 0.9330
# Epoch 32/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2090 - accuracy: 0.9345
# Epoch 33/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1771 - accuracy: 0.9379
# Epoch 34/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1640 - accuracy: 0.9429
# Epoch 35/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1705 - accuracy: 0.9402
# Epoch 36/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1763 - accuracy: 0.9383
# Epoch 37/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1415 - accuracy: 0.9499
# Epoch 38/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1518 - accuracy: 0.9443
# Epoch 39/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1629 - accuracy: 0.9411
# Epoch 40/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1547 - accuracy: 0.9428
# Epoch 41/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1430 - accuracy: 0.9491
# Epoch 42/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1314 - accuracy: 0.9514
# Epoch 43/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1633 - accuracy: 0.9407
# Epoch 44/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1400 - accuracy: 0.9485
# Epoch 45/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1283 - accuracy: 0.9497
# Epoch 46/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1395 - accuracy: 0.9477
# Epoch 47/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1365 - accuracy: 0.9473
# Epoch 48/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1226 - accuracy: 0.9540
# Epoch 49/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1222 - accuracy: 0.9546
# Epoch 50/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1298 - accuracy: 0.9499
# Epoch 51/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1290 - accuracy: 0.9530
# Epoch 52/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1108 - accuracy: 0.9590
# Epoch 53/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1267 - accuracy: 0.9505
# Epoch 54/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1143 - accuracy: 0.9578
# Epoch 55/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1237 - accuracy: 0.9541
# Epoch 56/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1097 - accuracy: 0.9587
# Epoch 57/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1427 - accuracy: 0.9461
# Epoch 58/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1186 - accuracy: 0.9548
# Epoch 59/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1217 - accuracy: 0.9533
# Epoch 60/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1250 - accuracy: 0.9522
# Epoch 61/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1095 - accuracy: 0.9589
# Epoch 62/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.0986 - accuracy: 0.9625
# Epoch 63/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1223 - accuracy: 0.9531
# Epoch 64/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1055 - accuracy: 0.9585
# Epoch 65/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1226 - accuracy: 0.9521
# Epoch 66/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1132 - accuracy: 0.9575
# Epoch 67/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.0982 - accuracy: 0.9622
# Epoch 68/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1014 - accuracy: 0.9621
# Epoch 69/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1132 - accuracy: 0.9554
# Epoch 70/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1076 - accuracy: 0.9583
# Epoch 71/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1038 - accuracy: 0.9598
# Epoch 72/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.0990 - accuracy: 0.9626
# Epoch 73/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1076 - accuracy: 0.9591
# Epoch 74/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1080 - accuracy: 0.9592
# Epoch 75/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0929 - accuracy: 0.9646
# Epoch 76/100
# 589/589 [==============================] - 3s 4ms/step - loss: 0.1101 - accuracy: 0.9596
# Epoch 77/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1253 - accuracy: 0.9526
# Epoch 78/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0965 - accuracy: 0.9624
# Epoch 79/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0968 - accuracy: 0.9631
# Epoch 80/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1050 - accuracy: 0.9603
# Epoch 81/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1046 - accuracy: 0.9600
# Epoch 82/100
# 589/589 [==============================] - 3s 4ms/step - loss: 0.1028 - accuracy: 0.9597
# Epoch 83/100
# 589/589 [==============================] - 3s 4ms/step - loss: 0.0914 - accuracy: 0.9649
# Epoch 84/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0877 - accuracy: 0.9678
# Epoch 85/100
# 589/589 [==============================] - 2s 4ms/step - loss: 0.1070 - accuracy: 0.9584
# Epoch 86/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1005 - accuracy: 0.9618
# Epoch 87/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0937 - accuracy: 0.9658
# Epoch 88/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0921 - accuracy: 0.9663
# Epoch 89/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0999 - accuracy: 0.9624
# Epoch 90/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0926 - accuracy: 0.9633
# Epoch 91/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0981 - accuracy: 0.9633
# Epoch 92/100
# 584/589 [============================>.] - ETA: 0s - loss: 0.0923 - accuracy: 0.9648Restoring model weights from the end of the best epoch: 84.
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0924 - accuracy: 0.9647
# Epoch 92: early stopping
# 253/253 [==============================] - 2s 5ms/step
#
# === ANN (2 Layers) - Training Summary ===
# Loss       : 0.1190
# Accuracy   : 0.9440
#
# === ANN (2 Layers) - Test Summary ===
# Loss       : 0.1146
# Accuracy   : 0.9453
#
# === ANN (2 Layers) Evaluation ===
# Accuracy  : 0.9453
# Precision : 0.9485
# Recall    : 0.9453
# F1 Score  : 0.9450

# %% [markdown]
# ## 7) Model: ANN (3-layer)

# %%
# Features & classes
n_features = x_train.shape[1]
n_classes = len(np.unique(y_train))

# Define model
ann3 = Sequential([
    Dense(128, activation='relu', input_shape=(n_features,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(n_classes, activation='softmax')
])

# Compile model
ann3.compile(optimizer=Adam(learning_rate=0.001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# Early stopping (monitor training loss)
early_stop = EarlyStopping(
    monitor='loss',
    patience=8,
    restore_best_weights=True,
    verbose=1
)

# Train
history = ann3.fit(
    x_train, y_train,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate sets
train_loss, train_acc = ann3.evaluate(x_train, y_train, verbose=0)
test_loss, test_acc = ann3.evaluate(x_test, y_test, verbose=0)

# Predictions
y_pred = np.argmax(ann3.predict(x_test), axis=1)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Create directory and save model
os.makedirs("gas&env_models", exist_ok=True)
ann3.save("gas&env_models/ann_3layer_model_s.keras")

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== ANN (3 Layers) - Training Summary ===")
print(f"Loss       : {train_loss:.4f}")
print(f"Accuracy   : {train_acc:.4f}")

print("\n=== ANN (3 Layers) - Test Summary ===")
print(f"Loss       : {test_loss:.4f}")
print(f"Accuracy   : {test_acc:.4f}")

print("\n=== ANN (3 Layers) Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# 1️ Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title("Confusion Matrix - ANN (3 Layers)")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# 2️ Accuracy & Loss Curves
epochs_ran = len(history.history['accuracy'])
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(range(1, epochs_ran+1), history.history['accuracy'], label='Train Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(range(1, epochs_ran+1), history.history['loss'], label='Train Loss')
plt.title('Training Loss (Early Stopping Monitored)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 589/589 [==============================] - 6s 6ms/step - loss: 4.9397 - accuracy: 0.6797
# Epoch 2/100
# 589/589 [==============================] - 3s 6ms/step - loss: 1.8163 - accuracy: 0.7500
# Epoch 3/100
# 589/589 [==============================] - 4s 6ms/step - loss: 1.6371 - accuracy: 0.7718
# Epoch 4/100
# 589/589 [==============================] - 4s 6ms/step - loss: 1.2766 - accuracy: 0.7820
# Epoch 5/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.7934 - accuracy: 0.8207
# Epoch 6/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.6530 - accuracy: 0.8291
# Epoch 7/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.5897 - accuracy: 0.8364
# Epoch 8/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.5719 - accuracy: 0.8413
# Epoch 9/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.4382 - accuracy: 0.8664
# Epoch 10/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.3953 - accuracy: 0.8716
# Epoch 11/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.3359 - accuracy: 0.8816
# Epoch 12/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.3580 - accuracy: 0.8783
# Epoch 13/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2411 - accuracy: 0.9098
# Epoch 14/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.2517 - accuracy: 0.9088
# Epoch 15/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.2612 - accuracy: 0.9053
# Epoch 16/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2430 - accuracy: 0.9080
# Epoch 17/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2297 - accuracy: 0.9127
# Epoch 18/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.2295 - accuracy: 0.9133
# Epoch 19/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1976 - accuracy: 0.9236
# Epoch 20/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1830 - accuracy: 0.9282
# Epoch 21/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1952 - accuracy: 0.9243
# Epoch 22/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1805 - accuracy: 0.9307
# Epoch 23/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.1653 - accuracy: 0.9363
# Epoch 24/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1999 - accuracy: 0.9258
# Epoch 25/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1652 - accuracy: 0.9345
# Epoch 26/100
# 589/589 [==============================] - 4s 6ms/step - loss: 0.1449 - accuracy: 0.9427
# Epoch 27/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1607 - accuracy: 0.9388
# Epoch 28/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1594 - accuracy: 0.9395
# Epoch 29/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1332 - accuracy: 0.9456
# Epoch 30/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1395 - accuracy: 0.9456
# Epoch 31/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1307 - accuracy: 0.9494
# Epoch 32/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1690 - accuracy: 0.9372
# Epoch 33/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1319 - accuracy: 0.9481
# Epoch 34/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1270 - accuracy: 0.9516
# Epoch 35/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1308 - accuracy: 0.9497
# Epoch 36/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1309 - accuracy: 0.9491
# Epoch 37/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1214 - accuracy: 0.9537
# Epoch 38/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1268 - accuracy: 0.9497
# Epoch 39/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1237 - accuracy: 0.9511
# Epoch 40/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1242 - accuracy: 0.9515
# Epoch 41/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1242 - accuracy: 0.9522
# Epoch 42/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1192 - accuracy: 0.9538
# Epoch 43/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1189 - accuracy: 0.9539
# Epoch 44/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1167 - accuracy: 0.9535
# Epoch 45/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1145 - accuracy: 0.9545
# Epoch 46/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1103 - accuracy: 0.9575
# Epoch 47/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1194 - accuracy: 0.9541
# Epoch 48/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.1076 - accuracy: 0.9588
# Epoch 49/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1054 - accuracy: 0.9573
# Epoch 50/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1116 - accuracy: 0.9556
# Epoch 51/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1100 - accuracy: 0.9569
# Epoch 52/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1046 - accuracy: 0.9585
# Epoch 53/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1051 - accuracy: 0.9596
# Epoch 54/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1015 - accuracy: 0.9597
# Epoch 55/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1297 - accuracy: 0.9510
# Epoch 56/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1038 - accuracy: 0.9614
# Epoch 57/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0953 - accuracy: 0.9642
# Epoch 58/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1015 - accuracy: 0.9585
# Epoch 59/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1242 - accuracy: 0.9534
# Epoch 60/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0927 - accuracy: 0.9639
# Epoch 61/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1006 - accuracy: 0.9630
# Epoch 62/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1079 - accuracy: 0.9578
# Epoch 63/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0886 - accuracy: 0.9650
# Epoch 64/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0839 - accuracy: 0.9687
# Epoch 65/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0855 - accuracy: 0.9667
# Epoch 66/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1076 - accuracy: 0.9593
# Epoch 67/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0816 - accuracy: 0.9685
# Epoch 68/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1064 - accuracy: 0.9591
# Epoch 69/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0910 - accuracy: 0.9659
# Epoch 70/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.1002 - accuracy: 0.9621
# Epoch 71/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0950 - accuracy: 0.9624
# Epoch 72/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0830 - accuracy: 0.9689
# Epoch 73/100
# 589/589 [==============================] - 3s 5ms/step - loss: 0.0889 - accuracy: 0.9666
# Epoch 74/100
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0841 - accuracy: 0.9677
# Epoch 75/100
# 583/589 [============================>.] - ETA: 0s - loss: 0.0997 - accuracy: 0.9637Restoring model weights from the end of the best epoch: 67.
# 589/589 [==============================] - 3s 6ms/step - loss: 0.0996 - accuracy: 0.9638
# Epoch 75: early stopping
# 253/253 [==============================] - 1s 5ms/step
#
# === ANN (3 Layers) - Training Summary ===
# Loss       : 0.0891
# Accuracy   : 0.9686
#
# === ANN (3 Layers) - Test Summary ===
# Loss       : 0.0895
# Accuracy   : 0.9700
#
# === ANN (3 Layers) Evaluation ===
# Accuracy  : 0.9700
# Precision : 0.9706
# Recall    : 0.9700
# F1 Score  : 0.9700

# %% [markdown]
# ## 8) Model: K-Nearest Neighbors (KNN)

# %%
# Train model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)

# Predict
y_pred = knn.predict(x_test)

# Create directory 
os.makedirs("gas&env_models", exist_ok=True)

# Save model
with open(os.path.join("gas&env_models", "knn_model_s.pkl"), "wb") as f:
    pickle.dump(knn, f)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Append results
results.append(evaluate_model("KNN", y_test, y_pred))

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== KNN Classifier Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title("Confusion Matrix - KNN Classifier")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Classification Report (heatmap)
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(8,4))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap="Greens", fmt=".2f")
plt.title("Classification Report - KNN Classifier")
plt.ylabel("Classes")
plt.xlabel("Metrics")
plt.tight_layout()
plt.show()
# Out:
# === KNN Evaluation ===
# Accuracy  : 0.9874
# Precision : 0.9875
# Recall    : 0.9874
# F1 Score  : 0.9874
#
# === KNN Classifier Evaluation ===
# Accuracy  : 0.9874
# Precision : 0.9875
# Recall    : 0.9874
# F1 Score  : 0.9874

# %% [markdown]
# ## 9) Model: Gradient Boosting

# %%
from sklearn.preprocessing import LabelEncoder
# Encode target labels
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Train model
gb = GradientBoostingClassifier(random_state=42)
gb.fit(x_train, y_train)

# Predict
y_pred = gb.predict(x_test)

# Create directory 
os.makedirs("gas&env_models", exist_ok=True)

# Save model
with open(os.path.join("gas&env_models", "gradient_boost_model_s.pkl"), "wb") as f:
    pickle.dump(gb, f)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Append results
results.append(evaluate_model("Gradient Boost", y_test, y_pred))

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== Gradient Boosting Classifier Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', cbar=False)
plt.title("Confusion Matrix - Gradient Boosting Classifier")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Classification Report (heatmap)
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(8,4))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap="Purples", fmt=".2f")
plt.title("Classification Report - Gradient Boosting Classifier")
plt.ylabel("Classes")
plt.xlabel("Metrics")
plt.tight_layout()
plt.show()

# Accuracy vs Other Metrics Bar Plot
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]
# Out:
# === Gradient Boost Evaluation ===
# Accuracy  : 0.9988
# Precision : 0.9988
# Recall    : 0.9988
# F1 Score  : 0.9988
#
# === Gradient Boosting Classifier Evaluation ===
# Accuracy  : 0.9988
# Precision : 0.9988
# Recall    : 0.9988
# F1 Score  : 0.9988

# %% [markdown]
# ## 10) Model: XGBoost

# %%
# Train model
xgb = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)
xgb.fit(x_train, y_train)

# Predict
y_pred = xgb.predict(x_test)

# Create directory (fix typo: spector → specter)
os.makedirs("gas&env_models", exist_ok=True)

# Save model
with open(os.path.join("gas&env_models", "xgboost_model_s.pkl"), "wb") as f:
    pickle.dump(xgb, f)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Append results
results.append(evaluate_model("XGBoost", y_test, y_pred))

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== XGBoost Classifier Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', cbar=False)
plt.title("Confusion Matrix - XGBoost Classifier")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Classification Report (heatmap)
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(8,4))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Classification Report - XGBoost Classifier")
plt.ylabel("Classes")
plt.xlabel("Metrics")
plt.tight_layout()
plt.show()

# Accuracy vs Other Metrics Bar Plot
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]
# Out:
# D:\food spoilage\venv\Lib\site-packages\xgboost\training.py:199: UserWarning: [21:11:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === XGBoost Evaluation ===
# Accuracy  : 0.9990
# Precision : 0.9990
# Recall    : 0.9990
# F1 Score  : 0.9990
#
# === XGBoost Classifier Evaluation ===
# Accuracy  : 0.9990
# Precision : 0.9990
# Recall    : 0.9990
# F1 Score  : 0.9990

# %% [markdown]
# ## 11) Model: CNN (1D for tabular data)
# We reshape data to (samples, timesteps, features) with features as timesteps and 1 channel.

# %%
# Prepare data for 1D CNN
x_train_cnn = np.expand_dims(x_train, axis=-1)
x_test_cnn = np.expand_dims(x_test, axis=-1)

print("x_train_cnn shape:", x_train_cnn.shape)
print("x_test_cnn shape:", x_test_cnn.shape)

# Define model
cnn = Sequential([
    Conv1D(64, 3, activation='relu', input_shape=(x_train_cnn.shape[1], 1)),
    MaxPooling1D(2),
    Conv1D(32, 3, activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(n_classes, activation='softmax')
])

# Compile model
cnn.compile(optimizer=Adam(learning_rate=0.001),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

# Early stopping (monitor training loss)
early_stop = EarlyStopping(
    monitor='loss',
    patience=8,
    restore_best_weights=True,
    verbose=1
)

# Train model with early stopping
history = cnn.fit(
    x_train_cnn, y_train,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Predict
y_pred = np.argmax(cnn.predict(x_test_cnn), axis=1)

# Create directory
os.makedirs("gas&env_models", exist_ok=True)

# Save model
cnn.save(os.path.join("gas&env_models", "cnn_model_s.h5"))

# Evaluate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)

# Append results
results.append(evaluate_model("CNN", y_test, y_pred))

# ===========================
#       TEXTUAL SUMMARY
# ===========================
print("\n=== CNN Classifier Evaluation ===")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

# ===========================
#       VISUALIZATIONS
# ===========================

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', cbar=False)
plt.title("Confusion Matrix - CNN Classifier")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
plt.show()

# Classification Report (heatmap)
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(8,4))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Classification Report - CNN Classifier")
plt.ylabel("Classes")
plt.xlabel("Metrics")
plt.tight_layout()
plt.show()

# Accuracy & Loss Curves
epochs_ran = len(history.history['accuracy'])
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(range(1, epochs_ran+1), history.history['accuracy'], label='Train Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(range(1, epochs_ran+1), history.history['loss'], label='Train Loss')
plt.title('Training Loss (Early Stopping Monitored)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Performance Bar Plot
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]
# Out:
# x_train_cnn shape: (18819, 9, 1)
# x_test_cnn shape: (8066, 9, 1)
# WARNING:tensorflow:From D:\food spoilage\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/100
# 589/589 [==============================] - 8s 8ms/step - loss: 2.3552 - accuracy: 0.6944
# Epoch 2/100
# 589/589 [==============================] - 4s 8ms/step - loss: 0.6008 - accuracy: 0.7700
# Epoch 3/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.4952 - accuracy: 0.8000
# Epoch 4/100
# 589/589 [==============================] - 4s 8ms/step - loss: 0.4511 - accuracy: 0.8084
# Epoch 5/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.3758 - accuracy: 0.8470
# Epoch 6/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.3230 - accuracy: 0.8697
# Epoch 7/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.3026 - accuracy: 0.8795
# Epoch 8/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.2606 - accuracy: 0.8979
# Epoch 9/100
# 589/589 [==============================] - 4s 7ms/step - loss: 0.2611 - accuracy: 0.8997
# Epoch 10/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.2365 - accuracy: 0.9074
# Epoch 11/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.2209 - accuracy: 0.9174
# Epoch 12/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1980 - accuracy: 0.9228
# Epoch 13/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1972 - accuracy: 0.9252
# Epoch 14/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.2074 - accuracy: 0.9210
# Epoch 15/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1739 - accuracy: 0.9353
# Epoch 16/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1958 - accuracy: 0.9251
# Epoch 17/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1729 - accuracy: 0.9346
# Epoch 18/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1676 - accuracy: 0.9366
# Epoch 19/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.1677 - accuracy: 0.9343
# Epoch 20/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.2125 - accuracy: 0.9210
# Epoch 21/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1617 - accuracy: 0.9422
# Epoch 22/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1588 - accuracy: 0.9404
# Epoch 23/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1399 - accuracy: 0.9483
# Epoch 24/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1388 - accuracy: 0.9476
# Epoch 25/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1308 - accuracy: 0.9499
# Epoch 26/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1666 - accuracy: 0.9388
# Epoch 27/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1276 - accuracy: 0.9495
# Epoch 28/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1285 - accuracy: 0.9498
# Epoch 29/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1187 - accuracy: 0.9544
# Epoch 30/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1091 - accuracy: 0.9583
# Epoch 31/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1241 - accuracy: 0.9557
# Epoch 32/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1100 - accuracy: 0.9592
# Epoch 33/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1103 - accuracy: 0.9587
# Epoch 34/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1154 - accuracy: 0.9571
# Epoch 35/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1081 - accuracy: 0.9598
# Epoch 36/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.1042 - accuracy: 0.9609
# Epoch 37/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1097 - accuracy: 0.9600
# Epoch 38/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0909 - accuracy: 0.9661
# Epoch 39/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0951 - accuracy: 0.9646
# Epoch 40/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.1110 - accuracy: 0.9603
# Epoch 41/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0951 - accuracy: 0.9650
# Epoch 42/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.1055 - accuracy: 0.9616
# Epoch 43/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0918 - accuracy: 0.9672
# Epoch 44/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0957 - accuracy: 0.9642
# Epoch 45/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0891 - accuracy: 0.9663
# Epoch 46/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0826 - accuracy: 0.9699
# Epoch 47/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0873 - accuracy: 0.9675
# Epoch 48/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0825 - accuracy: 0.9684
# Epoch 49/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0830 - accuracy: 0.9692
# Epoch 50/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0732 - accuracy: 0.9730
# Epoch 51/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0696 - accuracy: 0.9749
# Epoch 52/100
# 589/589 [==============================] - 6s 10ms/step - loss: 0.0822 - accuracy: 0.9692
# Epoch 53/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0820 - accuracy: 0.9694
# Epoch 54/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0706 - accuracy: 0.9739
# Epoch 55/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0809 - accuracy: 0.9705
# Epoch 56/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0708 - accuracy: 0.9742
# Epoch 57/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0672 - accuracy: 0.9744
# Epoch 58/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0717 - accuracy: 0.9749
# Epoch 59/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0753 - accuracy: 0.9725
# Epoch 60/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0755 - accuracy: 0.9739
# Epoch 61/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0654 - accuracy: 0.9753
# Epoch 62/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0720 - accuracy: 0.9741
# Epoch 63/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0669 - accuracy: 0.9751
# Epoch 64/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0730 - accuracy: 0.9743
# Epoch 65/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0527 - accuracy: 0.9817
# Epoch 66/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0725 - accuracy: 0.9735
# Epoch 67/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0578 - accuracy: 0.9788
# Epoch 68/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0679 - accuracy: 0.9749
# Epoch 69/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0746 - accuracy: 0.9744
# Epoch 70/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0526 - accuracy: 0.9798
# Epoch 71/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0560 - accuracy: 0.9797
# Epoch 72/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0560 - accuracy: 0.9793
# Epoch 73/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0690 - accuracy: 0.9763
# Epoch 74/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0477 - accuracy: 0.9812
# Epoch 75/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0604 - accuracy: 0.9770
# Epoch 76/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0611 - accuracy: 0.9785
# Epoch 77/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0581 - accuracy: 0.9799
# Epoch 78/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0562 - accuracy: 0.9794
# Epoch 79/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0554 - accuracy: 0.9793
# Epoch 80/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0454 - accuracy: 0.9840
# Epoch 81/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0560 - accuracy: 0.9790
# Epoch 82/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0561 - accuracy: 0.9796
# Epoch 83/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0488 - accuracy: 0.9830
# Epoch 84/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0471 - accuracy: 0.9827
# Epoch 85/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0432 - accuracy: 0.9842
# Epoch 86/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0661 - accuracy: 0.9776
# Epoch 87/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0474 - accuracy: 0.9831
# Epoch 88/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0523 - accuracy: 0.9809
# Epoch 89/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0541 - accuracy: 0.9802
# Epoch 90/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0413 - accuracy: 0.9846
# Epoch 91/100
# 589/589 [==============================] - 6s 9ms/step - loss: 0.0478 - accuracy: 0.9832
# Epoch 92/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0443 - accuracy: 0.9840
# Epoch 93/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0420 - accuracy: 0.9849
# Epoch 94/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0547 - accuracy: 0.9812
# Epoch 95/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0604 - accuracy: 0.9798
# Epoch 96/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0393 - accuracy: 0.9853
# Epoch 97/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0441 - accuracy: 0.9838
# Epoch 98/100
# 589/589 [==============================] - 5s 8ms/step - loss: 0.0455 - accuracy: 0.9841
# Epoch 99/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0436 - accuracy: 0.9851
# Epoch 100/100
# 589/589 [==============================] - 5s 9ms/step - loss: 0.0485 - accuracy: 0.9819
# 253/253 [==============================] - 2s 6ms/step
# D:\food spoilage\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# === CNN Evaluation ===
# Accuracy  : 0.9485
# Precision : 0.9514
# Recall    : 0.9485
# F1 Score  : 0.9485
#
# === CNN Classifier Evaluation ===
# Accuracy  : 0.9485
# Precision : 0.9514
# Recall    : 0.9485
# F1 Score  : 0.9485
